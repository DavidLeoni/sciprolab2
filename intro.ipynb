# %%
import jupman
jupman.init()
# Out:
# <style>
#
#     #jupman-nav {
#         position: fixed;
#         top: 10px;
#         left: 5px;
#         background: white;
#         width: 200px;
#         padding: 10px;
#         z-index: 10;
#     }
#
#     /* style="background: rgba(255, 255, 255, 0);" class="unstyled" */
#
#     #jupman-toc {
#         position: fixed;
#         top: 100px;
#         left: -55px;
#         background: rgba(255, 255, 255, 0);
#
#         height: 80%;
#         width: 200px;
#         padding: 20px;
#         z-index: 10;
#         overflow-y: scroll;
#             /* font-size: 50%; */
#     }
#
#
#
#     code {
#         background-color:rgb(245, 249, 249) !important;
#     }
#
#
#     .jupman-nav-item {
#         font-weight:bold;
#         font-size:120%
#     }
#
#     .jupman-chapter-link {
#         font-size:150%;
#         margin-right:15px;
#     }
#
#     .jupman-chapter-link a {
#         text-decoration: none;
#     }
#
#     .jupman-title {
#         font-size:250%;
# ...

# %% [markdown]
# # Home
#
# ## Presentation
#
# Website for algorithms lab of Scientific Programming course, AA 2017/18
#
# Teaching assistant:
#
# * David Leoni,  david.leoni [AT] unitn.it, University of Trento
#
#
# This work is licensed under a Creative Commons Attribution 4.0 License  [CC-BY](https://creativecommons.org/licenses/by/4.0/)
#
# ![](img/cc-by.png)

# %% [markdown]
# ## News
#
# - 14 Jun 2018: Published [2018-06-11 exam solution](past-exams/2018-06-11/exam-2018-06-11.ipynb)
# - 05 Feb 2018: Published [2018-02-05 exam solution](past-exams/2018-02-05/exam-2018-02-05.ipynb)
# - 21 Jan 2018: Published [2018-01-16 exam solution](past-exams/2018-01-16/exam-2018-01-16.ipynb)
# - 29 Dic 2017: Published [midterm solution](past-exams/2017-12-21/exam-2017-12-21.ipynb)
# - 13 Nov 2017: Moved website from old [davidleoni.github.io/algolab](https://davidleoni.github.io/algolab) to [sciprolab2.readthedocs.io](https://sciprolab2.readthedocs.io)

# %% [markdown]
#
#
# ## Exams
#
# See exams schedule on  <a href="http://cricca.disi.unitn.it/montresor/teaching/scientific-programming/exams/" target="_blank"> Alberto Montresor's site</a>
#
#
# ### Exam modalities
#
# There will always be an exercise on dynamic programming, curated by Montresor, plus two other exercises made by me on topics seen in lab.
#
# Algolab exams are open book. You can bring a printed version of the material listed below.
#
# Exam will take place in the lab with no internet access. You will only be able to access a folder with this documentation:
#
# * [Sciprog Algolab website](http://davidleoni.github.io/algolab)
# * [Alberto Montresor slides](http://cricca.disi.unitn.it/montresor/teaching/scientific-programming/)
# * [Luca bianco slides](http://sciprolab1.readthedocs.org)
# * [Python 3 documentation](https://docs.python.org/3/)
#     * In particular, [Unittest docs](https://docs.python.org/3/library/unittest.html)
# * [The course book 'Problem Solving with Algorithms and Data Structures using Python'](http://interactivepython.org/runestone/static/pythonds/index.html)
#
# So if you need to look up some Python function, please start today learning how to search documentation on Python website.

# %% [markdown]
# ### Past exams
#
# **Academic year 2017-18:**
#
# * [2017-12-21 midterm](past-exams/2017-12-21/exam-2017-12-21.ipynb)
# * [2018-01-16 exam (Part A + Part B)](past-exams/2018-01-16/exam-2018-01-16.ipynb)
# * [2018-02-05 exam (Part A + Part B)](past-exams/2018-02-05/exam-2018-02-05.ipynb)
# * [2018-06-11 exam (Part A + Part B)](past-exams/2018-06-11/exam-2018-06-11.ipynb)
#
# **Academic year 2016-17:** [davidleoni.github.io/algolab/past-exams.html](https://davidleoni.github.io/algolab/past-exams.html)
# <div class="alert alert-warning">
#
# **WARNING:** Exams of AA year 2016-17 are definitely useful, but:<br/><br/>
#
# - keep in mind that they are for Python 2 - in this course we use Python 3 <br/>
# - some contain exercises with pseudocode: this year we mostly use more Python code instead. <br/>
# - **MOST IMPORTANTLY: THIS YEAR THERE WILL BE DYNAMIC PROGRAMMING IN THE LAB EXAM !** <br/>
#
# </div>

# %% [markdown]
# ## Slides
#
# **Lab 1 Slides**
#
# Monday 13 Nov 2017
#
# **Lab Goals**
#
# * Going from theory taught by Prof. Alberto Montresor to Python 3 implementation
# * plus: some software engineering wisdom
#
# **How**
#
# * Hands-on approach
# * Performance considerations
# * Focus on correct code
# * Few Python functions
# * Will follow  [last year algorithms lab](https://davidleoni.github.io/algolab) BUT:
#
# ||last year | this year|
# |-|----------|----------|
# |Python version| Python 2| Python 3|
# |Psuedocode|y|not much|
# |Dynamic programming during exams|n|y|
#
#
# <br/>
# <div class="alert alert-warning">
#
# **WARNING**: Beware the _jupman_ !
#
# If you see around commands containing the word `jupman`, please ignore them, they are just for website publishing purposes.
# </div>
#
# **Lab Midterm?**
#
# * Probably
#
# **Exam**
#
# * open book
# * if you study, you get 30
#
# **Today**
#
# * [Chapter 0: Testing](testing.ipynb) with `unittest`
# * Start [Chapter 1: OOP: Object Oriented Programming](oop.ipynb)
#     * ComplexNumber: from dictionaries to classes
#     * start implementing class ComplexNumber
#
#
# Remember: to run tests, enter the following command in the terminal:
#
#
# ```bash
#     python -m unittest my-file
# ```
#
# <div class="alert alert-warning">
#
# **WARNING:** In the call above, DON'T append the extension <i>.py</i> to <i>my-file</i>
# </div>
#
# <div class="alert alert-warning">
# **WARNING:** Still, on the hard-disk the file MUST be named with a <i>.py</i> at the end, like <i>my-file.py</i>
# </div>
#
#
# **Lab 2 Slides**
#
# Friday 17 Nov 2017
#
# * Chapter 1: OOP: Object Oriented Programming
#     * Finish implementing [class ComplexNumber](oop.ipynb)
#
# **Lab 3 Slides**
#
# Monday 20 Nov 2017
#
# * More about testing in new section [Chapter 0 section: Error kinds](testing.ipynb#Error-kinds)
# * [Chapter 2, Algorithms on Python Lists](lists.ipynb)
#     * Considerations on [list performance](lists.ipynb#List-performance)
#     * Implementing [Selection sort](lists.ipynb#1-Implement-Selection-Sort)
#
# **Lab 4 Slides**
#
# Friday 24 Nov 2017
#
# * [Chapter 3.2, Data Structures - LinkedLists on Python Lists](linked-lists.ipynb)
#     * at least slow implementation
#     * versioning
#     * possibly faster size, append
#
# **Lab 5 Slides**
#
# Monday 27 Nov 2017
#
# * [Chapter 3.3, Data Structures - Queues](queues.ipynb)
#     * CircularQueue
#     * ItalianQueue (as LinkedList)
#
# **Lab 6 Slides**
#
# Friday 1 Dec 2017
#
# * [Chapter 4, Trees](trees.ipynb)
#     * GenericTree
#
# **Lab 7 Slides**
#
# Monday 4 Dec 2017
#
# * [Chapter 5, Graphs](graphs.ipynb)
#     * `DiGraph` description
#     * [Building graphs](graphs.ipynb#1.-Implement-building)
#
# **Lab 8 Slides**
#
# Thursday 7 Dec 2017
#
# * [Chapter 5, Graphs](graphs.ipynb)
#     * [Manipulating graphs](graphs.ipynb#2.-Manipulate-graphs)

# %% [markdown]
# ## Office hours
#
# To schedule a meeting, [see here](http://davidleoni.it/about-me/#office-hours)

# %% [markdown]
# ## Resources
#
# * Online book: [Problem Solving with Algorithms and Data Structures using Python](http://interactivepython.org/runestone/static/pythonds/index.html)
#     by Brad Miller and David Ranum
# * [Theory slides](http://cricca.disi.unitn.it/montresor/teaching/scientific-programming/slides/)  by Alberto Montresor
# * Will try to be consistent with [other lab module notes](http://sciprolab1.readthedocs.org) of Luca Bianco
# * [PythonTutor](http://www.pythontutor.com/visualize.html#mode=edit), a visual virtual machine (_very useful_! can also be found in examples inside the book!)
# * [Source code](https://github.com/DavidLeoni/sciprolab2) of these worksheets ([download zip](https://github.com/DavidLeoni/sciprolab2/archive/master.zip)), in [Jupyter Notebook](http://jupyter.org) format.
# * The internet ....
#
# ### Editors
#
# * [Spyder](https://pythonhosted.org/spyder/): Seems like a fine and simple editor
# * [Jupyter Notebook](http://jupyter.org): Nice environment to execute Python commands and display results like graphs. Allows to include documentation in Markdown format

# %% [markdown]
# ## Commandments
#
# <div class="alert alert-warning">
#
# **WARNING**: If you don't follow the Commandments, bad things happen!
# </div>
#
# <div class="alert alert-info" >
# **COMMANDMENT 1**: You shall test!
# </div>
#
# To run tests, enter the following command in the terminal:

# %% [markdown]
# Windows Anaconda:
#
# ```bash
#     python -m unittest my-file
# ```
#
# Linux/Mac: remember the three after python command:
#
# ```bash
#     python3 -m unittest my-file
# ```

# %% [markdown]
# <div class="alert alert-warning">
#
# **WARNING:** In the call above, DON'T append the extension <i>.py</i> to <i>my-file</i>
# <br/>
# **WARNING:** Still, on the hard-disk the file MUST be named with a _.py_ at the end, like _my-file.py_
# <br/>
# **WARNING:** If strange errors occur, make sure to be using python version **3**. Just run the interpreter and it will display the current version.
# </div>
#
# <div class="alert alert-info" >
#
# **COMMANDMENT 2:** You shall also write on paper!
# </div>
#
# If staring at the monitor doesn't work, help yourself and draw a representation of the state sof the program.
# Tables, nodes, arrows, all can help figuring out a solution for the problem.
# <br/>
# <br/>
# <div class="alert alert-info" >
#
# **COMMANDMENT 3:** You shall copy *exactly the same* function definitions as in the exercises!
# </div>
#
# For example don't write :
#
# ```python
#     def MY_selection_sort(A):
# ```

# %% [markdown]
# <div class="alert alert-info" >
#
# **COMMANDMENT 4:** You shall never ever reassign function parameters:
# </div>
#
# ```python
#
#     def myfun(i, s, L, D):
#
#         # You shall not do any of such evil, no matter what the type of the parameter is:
#         i = 666            # basic types (int, float, ...)
#         s = "666"          # strings
#         L = [666]          # containers
#         D = {"evil":666}   # dictionaries
#
#         # For the sole case of composite parameters like lists or dictionaries,
#         # you can write stuff like this IF AND ONLY IF the function specification
#         # requires you to modify the parameter internal elements (i.e. sorting a list
#         # or changing a dictionary field):
#
#         L[4] = 2             # list
#         D["my field"] = 5    # dictionary
#         C.my_field = 7       # class
# ```

# %% [markdown]
# <div class="alert alert-info">
#
# **COMMANDMENT 5:  You shall never ever reassign `self`:**
# </div>
#
# Never ever write horrors such as:
#
# ```python
#
# class MyClass
#     def my_method(self, x, y):
#         self = {a:666}  # since self is a kind of dictionary, you might be tempted to do like this
#                         # but to the outside world this will bring no effect.
#                         # For example, let's say somebody from outside makes a call like this:
#                         #    mc = MyClass()
#                         #    mc.my_method()
#                         # after the call mc will not point to {a:666}
#         self = ['666']  # self is only supposed to be a sort of dictionary and passed from outside
#         self = 6        # self is only supposed to be a sort of dictionary and passed from outside
# ```

# %% [markdown]
# <div class="alert alert-info" >
#
# **COMMANDMENT 6:** You shall never ever assign values to method calls:
# </div>
#
# _WRONG WRONG STUFF:_
#
# ```python
#
# my_fun() = 666
# my_fun() = '666'
# my_fun() = [666]
#
# ```
#
# _CORRECT STUFF:_
#
# With the assignment operator we want to store in the left side a value from the right side, so all of these are valid operations:
#
# ```python
# x = 5
# y = my_fun()
# z = []
# z[0] = 7
# d = {}
# d["a"] = 6
# ```
#
# Function calls such as `my_fun()` return instead results of calculations in a box that is created just for the purpose of the call and Python will just not allow us to reuse it as a variable. So whenever you see 'name()' at the left side, it _can't_ be possibly follewed by one equality `=` sign (but it can be followed by two equality signs `==` if you are performing a comparison).

# %% [markdown]
# <div class="alert alert-info" >
#
# **COMMANDMENT 7:** You shall use `return` command only if you see written _return_ in the function description!
# </div>
#
# If there is no `return` in function description, the function is intended to return `None`. In this case you don't even need to write `return None`, as Python will do it implicitly for you.
